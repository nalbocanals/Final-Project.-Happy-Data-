/Users/nuria/Documents/datasciencecourse/FINAL PROJECT/apps_selfesteem.xlsx')

# %%
app_selfesteem
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1594028370-1108  https://play.google.com/store/search?q=autoest...
# 1      1594028276-984  https://play.google.com/store/search?q=autoest...
# 2     1594028373-1111  https://play.google.com/store/search?q=autoest...
# 3     1594028362-1095  https://play.google.com/store/search?q=autoest...
# 4     1594028362-1098  https://play.google.com/store/search?q=autoest...
# ..                ...                                                ...
# 143    1594028274-979  https://play.google.com/store/search?q=autoest...
# 144   1594028379-1119  https://play.google.com/store/search?q=autoest...
# 145   1594028323-1053  https://play.google.com/store/search?q=autoest...
# 146   1594028376-1114  https://play.google.com/store/search?q=autoest...
# 147   1594028379-1120  https://play.google.com/store/search?q=autoest...
#
#                                                   Apps  \
# ...

# %%
apps_happiness_orig=pd.read_excel('/Users/nuria/Documents/datasciencecourse/FINAL PROJECT/appshealthdef_columns.xlsx')

# %%
apps_happiness_orig
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0      1592496746-533  https://play.google.com/store/search?q=salud%2...
# 1      1592496772-579  https://play.google.com/store/search?q=salud%2...
# 2      1592496691-432  https://play.google.com/store/search?q=salud%2...
# 3      1592496696-438  https://play.google.com/store/search?q=salud%2...
# 4      1592496742-524  https://play.google.com/store/search?q=salud%2...
# ..                ...                                                ...
# 178    1592496693-436  https://play.google.com/store/search?q=salud%2...
# 179    1592496763-562  https://play.google.com/store/search?q=salud%2...
# 180    1592496704-456  https://play.google.com/store/search?q=salud%2...
# 181    1592496723-488  https://play.google.com/store/search?q=salud%2...
# 182    1592496755-546  https://play.google.com/store/search?q=salud%2...
#
#                                                   apps  \
# ...

# %% [markdown]
# ##### CLEAN COLUMNS I'M NOT GOING TO USE

# %%
app_per_gr.head(1)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1594026578-696  https://play.google.com/store/search?q=crecimi...
#
#                    Apps                                          Apps-href  \
# 0  El Poder de la mente  https://play.google.com/store/apps/details?id=...
#
#            developer            type  rates downolads  \
# 0  Emprendedora apps  Estilo de vida    4.4  100.000+
#
#                                          lastreviews
# 0  Gauuu, que buena aplicación. Amo los temas de ...

# %%
app_per_gr.drop(['web-scraper-order','web-scraper-start-url','Apps-href'],axis=1,inplace=True)

# %%
app_per_gr.rename(columns={'Apps':'App','developer':'Developer','type':'Type','rates':'Rates','downolads':'Downloads+','lastreviews':'Last_reviews'},inplace=True)

# %%
app_per_gr
# Out:
#                                                   App  \
# 0                                El Poder de la mente
# 1        Audios de Autoestima💪Motivación😄Superación❤️
# 2    Goalmap: motivación, bienestar, metas personales
# 3                              Crecimiento Espiritual
# 4                       Mindfulness Meditación guiada
# ..                                                ...
# 173                          🧙 Aumenta tu Sabiduría 🧙
# 174                              El Poder de la mente
# 175                               Desarrollo Personal
# 176                    Autoayuda y Superación Libro 2
# 177                              Fabulous: ¡Motívame!
#
#                                  Developer                        Type  Rates  \
# 0                        Emprendedora apps              Estilo de vida    4.4
# 1                            DAVID B MARÍN                   Educación    4.6
# 2                                  GOALMAP               Productividad    3.3
# ...

# %%
appmotivationals.head(1)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1594027307-927  https://play.google.com/store/search?q=motivac...
#
#                                              Apps  \
# 0  Mentalidad Emprendedora - Frases de Motivación
#
#                                            Apps-href  \
# 0  https://play.google.com/store/apps/details?id=...
#
#                                              name  \
# 0  Mentalidad Emprendedora - Frases de Motivación
#
#                      developer       type  rate downloads  \
# 0  Wallpapers & Sounds Madness  Educación   4.1  100.000+
#
#                                          lastreviews
# 0  Excelente app. Realmente motivan a ser diferen...

# %%
appmotivationals.drop(['web-scraper-order','web-scraper-start-url','Apps-href','name'],axis=1,inplace=True)

# %%
appmotivationals.rename(columns={'Apps':'App','developer':'Developer','type':'Type','rate':'Rates','downloads':'Downloads+','lastreviews':'Last_reviews'},inplace=True)

# %%
apphappiness.head(1)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1594025949-567  https://play.google.com/store/search?q=felicid...
#
#                            App  \
# 0  Frases y fotos de Felicidad
#
#                                             App-href               developer  \
# 0  https://play.google.com/store/apps/details?id=...  Entertainment LTD Apps
#
#              type  rate downloads  \
# 0  Estilo de vida   4.7   10.000+
#
#                                          lastreviewa
# 0  Gracias por tan interesantes fotos y frases mu...

# %%
apphappiness.drop(['web-scraper-order','web-scraper-start-url','App-href'],axis=1, inplace=True)

# %%
apphappiness.rename(columns={'App':'App','developer':'Developer','type':'Type','rate':'Rates','downloads':'Downloads+','lastreviewa':'Last_reviews'},inplace=True)

# %%
app_menthealth.head(1)
# Out:
#                        App Developer               Type  Rates  Downloads+  \
# 0  Cíngulo: Terapia Guiada   Cíngulo  Salud y bienestar    4.9  1.000.000+
#
#                                         Last_reviews
# 0  De momento estoy subiendo mi grado de autoesti...

# %%
app_menthealth.drop(['web-scraper-order','web-scraper-start-url','Apps-href'],axis=1,inplace=True)

# %%
app_menthealth.rename(columns={'Apps':'App','developer':'Developer','type':'Type','rate':'Rates','downoalds':'Downloads+','lastreviews':'Last_reviews'},inplace=True)

# %%
app_selfesteem.head(1)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1594028370-1108  https://play.google.com/store/search?q=autoest...
#
#                  Apps                                          Apps-href  \
# 0  Test de Autoestima  https://play.google.com/store/apps/details?id=...
#
#                  name                       developer             type  rate  \
# 0  Test de Autoestima  Entretenimiento y curiosidades  Entretenimiento   2.0
#
#   downloads                                       lastreviewsa
# 0    1.000+  Solo puedes entrar al primer cuestionario, no ...

# %%
app_selfesteem.drop(['web-scraper-order','web-scraper-start-url','Apps-href'],axis=1,inplace=True)

# %%
app_selfesteem.drop(['name'],axis=1,inplace=True)

# %%
app_selfesteem.rename(columns={'Apps':'App','developer':'Developer','type':'Type','rate':'Rates','downloads':'Downloads+','lastreviewsa':'Last_reviews'},inplace=True)

# %%
apps_happiness_orig.head(1)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0    1592496746-533  https://play.google.com/store/search?q=salud%2...
#
#                          apps  \
# 0  Ejercicios para el cerebro
#
#                                            apps-href  \
# 0  https://play.google.com/store/apps/details?id=...
#
#                          name             typw  rate descarrgas  \
# 0  Ejercicios para el cerebro  Entretenimiento   4.5   100.000+
#
#          developer              update  \
# 0  ABC Programming  7 de abril de 2020
#
#                                              reviews
# 0  Muy buena !practicar a diario mejora mi atenci...

# %%
apps_happiness_orig.drop(['web-scraper-order','web-scraper-start-url','apps-href','name'],axis=1,inplace=True)

# %%
apps_happiness_orig.rename(columns={'apps':'App','developer':'Developer','typw':'Type','rate':'Rates','descarrgas':'Downloads+','reviews':'Last_reviews'},inplace=True)

# %%
app_selfesteem
# Out:
#                                                    App  \
# 0                                   Test de Autoestima
# 1                                  Aumentar Autoestima
# 2                                 Frases de Autoestima
# 3                D. Psique: Hábitos, Auto-conocimiento
# 4                D. Psique: Hábitos, Auto-conocimiento
# ..                                                 ...
# 143   Libros de Motivación Personal Gratis📚Superación💪
# 144                               Elevar la Autoestima
# 145  Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# 146                             Ser feliz Reto 30 días
# 147                               Elevar la Autoestima
#
#                           Developer                        Type  Rates  \
# 0    Entretenimiento y curiosidades             Entretenimiento    2.0
# 1                       NanchosApps              Estilo de vida    3.5
# 2                         KhoniaDev              Estilo de vida    4.3
# ...

# %%
apps_happiness_orig.drop(['update'],axis=1, inplace=True)

# %%
column_orders=['App','Developer','Type','Rates','Downloads+','Last_reviews']
apps_happiness_orig=apps_happiness_orig[column_orders]

# %% [markdown]
# ##### CONCAT ALL 6 DATASETS

# %%
apphappiness
# Out:
#                                                 App  \
# 0                       Frases y fotos de Felicidad
# 1                     Saludos De Buenos Días Gratis
# 2                    Feliz Cumpleaños: Fiesta&Velas
# 3                     Frases Feliz Dia de la Semana
# 4                       Feliz Cumpleaños con Musica
# ..                                              ...
# 158                      Smylife - Felicidad diaria
# 159                         Consejos para ser feliz
# 160  La Jarra de la Felicidad - diario de recuerdos
# 161                                 Radio Felicidad
# 162                                Ley de Atracción
#
#                        Developer               Type  Rates    downloads  \
# 0         Entertainment LTD Apps     Estilo de vida    4.7      10.000+
# 1                     kamvapps97    Entretenimiento    4.8     100.000+
# 2                        BabyBus         Educativos    4.1  10.000.000+
# ...

# %%
Apps_review_def=pd.concat([app_per_gr,appmotivationals,apphappiness,app_menthealth,app_selfesteem,apps_happiness_orig])

# %%
Apps_review_def
# Out:
#                                                    App  \
# 0                                 El Poder de la mente
# 1         Audios de Autoestima💪Motivación😄Superación❤️
# 2     Goalmap: motivación, bienestar, metas personales
# 3                               Crecimiento Espiritual
# 4                        Mindfulness Meditación guiada
# ..                                                 ...
# 178                           Meditación Guiada Gratis
# 179    Control y Monitor: Ansiedad, Ánimo y Autoestima
# 180            Pixels - Estados de Ánimo y Mindfulness
# 181                          Psicología Positiva Fácil
# 182  PSY online terapia psicologia. Сhat apoyo anón...
#
#                                  Developer                        Type  Rates  \
# 0                        Emprendedora apps              Estilo de vida    4.4
# 1                            DAVID B MARÍN                   Educación    4.6
# ...

# %%
Apps_review_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028 entries, 0 to 182
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   App           1028 non-null   object
#  1   Developer     1028 non-null   object
#  2   Type          1028 non-null   object
#  3   Rates         1028 non-null   float64
#  4   Downloads+    1028 non-null   object
#  5   Last_reviews  1026 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 56.2+ KB

# %%
#There are two apps without review

# %% [markdown]
# ##### SAVE THE CONCATENATED DATA SET INTO A .CSV FILE

# %%
Apps_review_def.to_csv("Apps_mental_health_happiness.csv",index=False)
