# %% [markdown]
# # FINAL PROJECT - PART 13 - GOOGLE TRANS
#
# In this part of the project I use Google Trans to translate the reviews that I web scraped from Google Play the first time.
# I translate them in English because I want to apply VADER to get the sentiment analysis scores and it only works in English.

# %%
import pandas as pd
import nltk

import warnings
warnings.filterwarnings("ignore")

# %%
app_health=pd.read_csv('/Users/nuria/Documents/datasciencecourse/FINAL PROJECT/Apps_Mental_health_def.csv')

# %%
app_health
# Out:
#      Unnamed: 0                                           App_name  \
# 0             0                         Ejercicios para el cerebro
# 1             1                             Ser feliz Reto 30 días
# 2             2               Moodpath - Depression & Anxiety Test
# 3             3                                desordenes mentales
# 4             4  Psicólogos Online, Diario emocional y Mindfulness
# ..          ...                                                ...
# 178         178                           Meditación Guiada Gratis
# 179         179    Control y Monitor: Ansiedad, Ánimo y Autoestima
# 180         180            Pixels - Estados de Ánimo y Mindfulness
# 181         181                          Psicología Positiva Fácil
# 182         182  PSY online terapia psicologia. Сhat apoyo anón...
#
#                        App_type  App_rate  App_downloads+      App_developer  \
# 0               Entretenimiento       4.5          100000    ABC Programming
# ...

# %%
app_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       183 non-null    int64
#  1   App_name         183 non-null    object
#  2   App_type         183 non-null    object
#  3   App_rate         183 non-null    float64
#  4   App_downloads+   183 non-null    int64
#  5   App_developer    183 non-null    object
#  6   App_last_update  183 non-null    object
#  7   App_review       183 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 11.6+ KB

# %%
#check the Apps that we don't have reviews and drop them
app_health[app_health.App_review=='No review']
# Out:
#      Unnamed: 0                  App_name           App_type  App_rate  \
# 69           69  Paradym: mental wellness  Salud y bienestar       4.5
# 109         109  Salud Mental - psicólogo  Salud y bienestar       3.0
#
#      App_downloads+ App_developer           App_last_update App_review
# 69             1000  Paradym Beta       14 de julio de 2019  No review
# 109            1000      USD Apps  29 de septiembre de 2018  No review

# %%
app_health.drop([69,109],inplace=True)

# %%
app_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181 entries, 0 to 182
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       181 non-null    int64
#  1   App_name         181 non-null    object
#  2   App_type         181 non-null    object
#  3   App_rate         181 non-null    float64
#  4   App_downloads+   181 non-null    int64
#  5   App_developer    181 non-null    object
#  6   App_last_update  181 non-null    object
#  7   App_review       181 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 12.7+ KB

# %%
#Drop the unnamed column thayt was added when I saved the .csv file
app_health.drop(columns='Unnamed: 0', inplace=True)

# %%
app_health
# Out:
#                                               App_name  \
# 0                           Ejercicios para el cerebro
# 1                               Ser feliz Reto 30 días
# 2                 Moodpath - Depression & Anxiety Test
# 3                                  desordenes mentales
# 4    Psicólogos Online, Diario emocional y Mindfulness
# ..                                                 ...
# 178                           Meditación Guiada Gratis
# 179    Control y Monitor: Ansiedad, Ánimo y Autoestima
# 180            Pixels - Estados de Ánimo y Mindfulness
# 181                          Psicología Positiva Fácil
# 182  PSY online terapia psicologia. Сhat apoyo anón...
#
#                        App_type  App_rate  App_downloads+      App_developer  \
# 0               Entretenimiento       4.5          100000    ABC Programming
# 1                Estilo de vida       4.0          100000         Metta Apps
# ...

# %%
pip install googletrans
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### PART 1 : TRANSLATING THE REVIEWS FROM SPANISH TO ENGLISH
#
# NOTE: Some reviews where not completed, so I have had to complete them in order to have the full review

# %%
from googletrans import Translator

# %%
#instantiate our translator
translator = Translator()
print(translator.translate('Hola').text)#translation
print(translator.translate('Hola').src) #original language
print(translator.translate('Hola').dest)#final languafe in which the original is translated
# Out:
# Hello
# es
# en

# %%
#Add a column in the dataset with the translations for each review
translated_df=app_health.copy()

# %%
#df_en.rename(columns=lambda x: translator.translate(x).text, inplace=True)

for item in translated_df.App_review:
    print(item)
    print(translator.translate(item).text,'\n\n\n')
    #translated_df['App_review_eng']=translator.translate(item).text
# Out:
# Muy buena !practicar a diario mejora mi atencion y memoria !
# Very good! Practicing daily improves my attention and memory!
#
#
#
# Maravillosa aplicación!! Agradezco que la hayan hecho y haberla encontrado, me súper ayudó!!
# Wonderful application !! I appreciate that they did it and found it, it really helped me !!
#
#
#
# Me gusta mucho, me hace prestar atención a mis emociones como nunca pensé:)
# I really like it, it makes me pay attention to my emotions like I never thought :)
#
#
#
# Excelente trabajo, muy completo y se Puede compartir con redes sociales. Gracias.
# Excellent work, very complete and can be shared with social networks. Thank you.
#
#
#
# Se ve genial, y muy bien diseñada. Pero claro, quien no tenga dinero para pagar la terapia, poca ayuda va a poder recibir. Recuerda, si tienes problemas emocionales y no tienes dinero, ningún psicólogo te podrá ayudar por pobre. Sé autodidacta, y aprende por tú cuenta para ayudarte a tí mismo. En el...Opinión completa
# ...

# %%
#reset the index because in the original dataframe there were two apps without reviews 
#and I have dropped them, when I iterate the loop for the translations these indexs are 
#missed and i get an error. I reset the indexes to avoid it

translated_df.reset_index(drop=True,inplace=True)

# %%
translated_df['App_review_engl']=translated_df['App_review'].apply(translator.translate).apply(getattr, args=('text',))

# %%
pd.set_option('display.max_rows', None)

# %%
translated_df['App_review_engl']
# Out:
# 0      Very good! Practicing daily improves my attent...
# 1      Wonderful application !! I appreciate that the...
# 2      I really like it, it makes me pay attention to...
# 3      Excellent work, very complete and can be share...
# 4      It looks great, and very well designed. But of...
# 5      I installed it just 4 days ago and I really lo...
# 6      Incredible application. It has plenty of tools...
# 7      this good this ap smack if you put your batter...
# 8      Maliiiiiiiiiisima. I can't see any disorder. I...
# 9      Good app helps me to take control and control ...
# 10     It's great, but it doesn't work anymore, they ...
# 11     A very helpful app, although I can't hear the ...
# 12     It is a good app to check your own mood and un...
# 13     Perfect! You can really access all the content...
# 14     The first self-evaluation was well thought out...
# 15     It's excellent. And it helps a lot to increase...
# ...

# %%
translated_df
# Out:
#                                               App_name  \
# 0                           Ejercicios para el cerebro
# 1                               Ser feliz Reto 30 días
# 2                 Moodpath - Depression & Anxiety Test
# 3                                  desordenes mentales
# 4    Psicólogos Online, Diario emocional y Mindfulness
# 5         Diario de animo y preguntas (anti depresión)
# 6         Medita con Petit BamBou: mindfulness y sueño
# 7                        Inteligencia emocional gratis
# 8                                  Desordenes mentales
# 9                           Smylife - Felicidad diaria
# 10   PSY online terapia psicologia. Сhat apoyo anón...
# 11                                   Ansiedad y estrés
# 12                Moodpath - Depression & Anxiety Test
# 13   Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# 14                             Cíngulo: Terapia Guiada
# 15        Mejor con Salud - Belleza, dieta y bienestar
# ...

# %%
#checking the reviews I have realized that there are some reviews that are incomplete
#i will check them

# %%
#df[df['model'].str.contains('ac')]
df_to_look_for_rev=translated_df[translated_df['App_review'].str.contains('Opinión completa')]

# %%
df_to_look_for_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 4 to 171
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   App_name         47 non-null     object
#  1   App_type         47 non-null     object
#  2   App_rate         47 non-null     float64
#  3   App_downloads+   47 non-null     int64
#  4   App_developer    47 non-null     object
#  5   App_last_update  47 non-null     object
#  6   App_review       47 non-null     object
#  7   App_review_engl  47 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.3+ KB

# %%
#We have 47 reviwes that we don't have the full review and I have to solve it
df_to_look_for_rev.App_name
# Out:
# 4      Psicólogos Online, Diario emocional y Mindfulness
# 5           Diario de animo y preguntas (anti depresión)
# 6           Medita con Petit BamBou: mindfulness y sueño
# 13     Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# 18                                            PsicoTests
# 20                            Psicologia de la Depresión
# 23          Diario de animo y preguntas (anti depresión)
# 36                         Pura Mente: Meditar es simple
# 41     Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# 43     Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# 46              Isotonos - Relajación, Meditación, Salud
# 53                              Calm: Meditación y Sueño
# 58                                        Como Ser Feliz
# 59                                  El Poder de la mente
# 62                      Wysa: tu entrenador de felicidad
# 69     Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# ...

# %%
#fill the reviews that are not completed

# %%
translated_df.head(1)
# Out:
#                      App_name         App_type  App_rate  App_downloads+  \
# 0  Ejercicios para el cerebro  Entretenimiento       4.5          100000
#
#      App_developer     App_last_update  \
# 0  ABC Programming  7 de abril de 2020
#
#                                           App_review  \
# 0  Muy buena !practicar a diario mejora mi atenci...
#
#                                      App_review_engl
# 0  Very good! Practicing daily improves my attent...

# %%
translated_df.iloc[4,6]='Se ve genial, y muy bien diseñada. Pero claro, quien no tenga dinero para pagar la terapia, poca ayuda va a poder recibir. Recuerda, si tienes problemas emocionales y no tienes dinero, ningún psicólogo te podrá ayudar por pobre. Sé autodidacta, y aprende por tú cuenta para ayudarte a tí mismo. En el caso de que no tengas dinero, es la única salida.'
translated_df.iloc[4,6]
# Out:
# 'Se ve genial, y muy bien diseñada. Pero claro, quien no tenga dinero para pagar la terapia, poca ayuda va a poder recibir. Recuerda, si tienes problemas emocionales y no tienes dinero, ningún psicólogo te podrá ayudar por pobre. Sé autodidacta, y aprende por tú cuenta para ayudarte a tí mismo. En el caso de que no tengas dinero, es la única salida.'

# %%
translated_df.iloc[93,6]='La aplicación está muy bien y van mejorando cositas. Las dos psicólogas que me han tratado se ven profesionales y muy dedicadas en su trabajo. Les agradezco sus intentos de ayudarme. También debo decir que supongo que cada caso es un mundo, pero para progresar de verdad también se necesitan meses o años de terapia, si tus problemas son "reales". Sale un poquito caro, pero si necesitas que te escuchen y te aconsejen está bien. Probadlo si os sentís estancados o no sabéis cómo solucionar algo, tal vez os puedan guiar un poco.'
translated_df.iloc[93,6]
# Out:
# 'La aplicación está muy bien y van mejorando cositas. Las dos psicólogas que me han tratado se ven profesionales y muy dedicadas en su trabajo. Les agradezco sus intentos de ayudarme. También debo decir que supongo que cada caso es un mundo, pero para progresar de verdad también se necesitan meses o años de terapia, si tus problemas son "reales". Sale un poquito caro, pero si necesitas que te escuchen y te aconsejen está bien. Probadlo si os sentís estancados o no sabéis cómo solucionar algo, tal vez os puedan guiar un poco.'

# %%
translated_df.iloc[118,6]='App muy práctica! losProfesionales que trabajan en esta aplicación, són buenos en su trabajo.Lo que encontras aqui: te ayudaran a llegar del Punto A al Punto B, hay un seguimiento de tus emociones y herramientas muy eficaces que podrás usar en caso de que tu Terapeuta no este disponible(son humanos también),para tener máximos resultados es importante hablar con trasparencia y Confiar en la gente que te esta ayudando.Además he sentido durante todo el camino que era un Ambiente Seguro y Hermético.'
translated_df.iloc[118,6]
# Out:
# 'App muy práctica! losProfesionales que trabajan en esta aplicación, són buenos en su trabajo.Lo que encontras aqui: te ayudaran a llegar del Punto A al Punto B, hay un seguimiento de tus emociones y herramientas muy eficaces que podrás usar en caso de que tu Terapeuta no este disponible(son humanos también),para tener máximos resultados es importante hablar con trasparencia y Confiar en la gente que te esta ayudando.Además he sentido durante todo el camino que era un Ambiente Seguro y Hermético.'

# %%
translated_df.iloc[5,6]='La instalé hace apenas 4 días y de veras, me encanta!. Siento como si tomara una gran cantidad de oxígeno cada que ingreso a la App a diario. Es como un pequeño refugio de tranquilidad, de paz, en el que de un modo muy sencillo puedo ser simplemente yo misma. Estaba buscando sugerencias de aplicaciones para que me ayudarán con la depresión y soy muy afortunada, encontré esta App. A sus creadores, muchas gracias y que Dios los bendiga. ☺️ LA SUPER RECOMIENDO!!! 🎉🎉🎉😘'
translated_df.iloc[5,6]
# Out:
# 'La instalé hace apenas 4 días y de veras, me encanta!. Siento como si tomara una gran cantidad de oxígeno cada que ingreso a la App a diario. Es como un pequeño refugio de tranquilidad, de paz, en el que de un modo muy sencillo puedo ser simplemente yo misma. Estaba buscando sugerencias de aplicaciones para que me ayudarán con la depresión y soy muy afortunada, encontré esta App. A sus creadores, muchas gracias y que Dios los bendiga. ☺️ LA SUPER RECOMIENDO!!! 🎉🎉🎉😘'

# %%
translated_df.iloc[23,6]='Me gusta la idea de tomarnos un momento a pensar y analizar nuestras respuestas. Nos ayuda a tomar conciencia. También tiene una opción para poner una nota de lo que quieras del día, lo cual nos ayuda a saber nuestro equilibrio mental a lo largo del tiempo. Me gustaría que tengan más opciones gratis, como poner contraseña pero sacando eso me gusta.'

# %%
translated_df.iloc[97,6]='Esta aplicacion es excelente, incluso en su version gratuita, solo con no tener anuncios ya vale la pena, apenas la he probado y ya he comprado la version Premium, no entiendo como se queja la gente de que no sea gratis cuando ronda los 3€ y es un pago único. Encantada de colaborar para que podais seguir desarrollando!!'

# %%
translated_df.iloc[6,6]='Increíble aplicación. Tiene un montón de herramientas tanto para la meditación guiada como para la meditación libre, sonidos y ayudas para ejercicios de respiración. Me encanta!! Además sin tener el modo premium tienes acceso a todas estas herramientas, pero con el premium tienes aun muchas más posibilidades y es muy económico. Totalmente recomendable.'

# %%
translated_df.iloc[73,6]='Es una buena aplicación, pero... Tienen muchos modos y tipos de meditación, pero solo el de inicio es gratis y por los demás tienes que pagar una cuota mensual que te vale como el Netflix o el hbo. La verdad, me estaba gustando hasta que vi esto, podrían vender paquetes por tipos por ejemplo...'

# %%
translated_df.iloc[161,6]='Muy buena. Sin embargo ha tenido fallos habían quitado las meditaciones de miedo, ansiedad y duelo que estaban gratis hasta las había descargado y se habían borrado. Tengo una serie seguidas de meditar de 63 pero se borró y se ahora solo muestra que solo he hecho 11. La verdad no sé que está ocurriendo a.mi me encanta esta app y si tuviera dinero me suscribia. Espero lo puedan arreglar :('

# %%
translated_df.iloc[13,6]='¡Perfecta! Realmente puedes acceder a todo el contenido de manera semi-gratis, osea, puedes ver anuncios para entrar a el contenido premium si no quieres pagar. De la docena de aplicaciones sobre meditación que ya había probado está sin duda alguna es la más completa aunque irónicamente decidí descargarla por curiosidad otra vez (no era la primera vez que lo hacía) y darle la oportunidad de meditar con ella todos los días; justo ahora no me podría encontrar más gratificado por ello.'

# %%
translated_df.iloc[41,6]='Excelente aplicación, me ayudo con mis problemas de ansiedad que en estos dias fueron intensos y aunque apenas la estoy usando me ha funcionando para relajarme, mil gracias, ya que tiene la opcion de si en estos momentos no puedes ser premium, te dan la oportunidad de ver esta sección por medio de anuncios, lo cual ninguna aplicación hace, gracias'

# %%
translated_df.iloc[43,6]='La mejor app para meditar, lo que me gustaría que agreguen es cuando estás en una meditación que la barra de volumen que se encuentra en la parte inferior no desaparezca, y otra que al inicio el cuadro grande creo que jala muchos recursos sería mejor quitarla porque a veces no se queda en la sería de meditaciones que estabas realizando , pero excelente app 😁'

# %%
translated_df.iloc[69,6]='Es la mejor aplicación que he probado. El diseño que tiene genera un acompañamiento ideal, es muy dinámica, armoniosa y sencilla. La claridad con la que describen las explicaciones y su forma de expresarse transmiten paz y motivan a continuar las prácticas. La variedad de sesiones y temáticas que abordan, dan complemento a las meditaciones, te invita a entenderte y conocerte a vos mismo. Hermosa aplicación, mis felicitaciones por tan comprometido trabajo.'

# %%
translated_df.iloc[18,6]='Es una ayuda para tratar de comprender ciertos comportamientos a través de test que estén validados, apenas empecé a usar la aplicación y me ha perecido muy interesante, ya que que hay muchos temas para estudiar y ahondar en el conocimiento tanto para estudiantes como los profesionales de la salud mental. Es un poco incómodo tanta publicidad.'

# %%
translated_df.iloc[162,6]='La aplicación está ok, pero desde que le metieron publicidad se ha convertido en una basura, no para de avisar indebidamente solo con la intención de meter más publicidad, cada vez que haces un test tienes que tragarte varios anuncios forzosos, es ABUSIVO!! No me van a dar más opcion que borrar la aplicación o denunciarla por publicidad intrusiva.'

# %%
translated_df.iloc[20,6]='Me gustó bastante, dice cosas muy ciertas que yo puedo asegurar, estoy segura de que muchas personas se sintieron identificadas con esto al igual que yo y no es nada fácil aceptar que lo estás viviendo, mucho menos sabiendo que tú familia no le toma importancia porque piensa que estás exagerando. Es maravilloso saber que existen personas como ustedes, gracias y lo voy a compartir, sobre todo con aquellas personas de las que más apoyo necesito.'

# %%
translated_df.iloc[36,6]='Quedé sorprendida. Es fácil. Y el tiempo de la meditación de 10 min paso rapidísimo cuando quise acordar ya estaba terminando. Me ayudó y lo recomiendo ... La solución está en nosotros. Y la verdad que enseña q la meditación es una herramienta para nuestro estilo de vida. No es religioso ni dogmatica'

# %%
translated_df.iloc[46,6]='La experiencia a sido excepcional. Con todas las opciones que tiene la aplicación, quisiera utilizarlas todas, pero la recomendación seria que cada persona revise sus prioridades. Y en cada opción mantenerla al menos 2 semanas, y en ultima utilizar 2 a la vez, una por la mañana y otra por la noche. La verdad, agradezco a las personas que participarón en poner a nuestra disposición esta aplicación. Gracias'

# %%
translated_df.iloc[90,6]='Hay algunos isotonos que no suenan y otros que se detienen súbitamente y al cabo de unos segundos sigue, lo cual es molesto. Por lo demás, bien. No son ni milagrosos ni mágicos ni lo pretenden, pero ayudan. El Nirvana - Dormir es mi favorito para dormir. Epsilon y Chakra del amor para meditar. Hay muchos otros que también son bastante útiles. Pero corrijan ese error de detención súbita!'

# %%
translated_df.iloc[157,6]='Es sencilla y su catálogo es muy útil, me ayuda cada noche a conciliar el sueño. Después de pasar por un pereodo de abstinencia por el uso de medicamentos para la ansiedad está app ayuda a equilibrar las emociones de mi cuerpo y a dormir tranquilo, simplemente genial, estoy infinitamente agradecido con los creadores.'

# %%
translated_df.iloc[53,6]='La versión gratuita es una farsa, tienes 7 días de prueba pero sólo habilitan el contenido del primer día. Estoy dispuesta a pagar por una prueba de un mes, pero ofrecen un único pago anual (por productos que te orientan en 7 días). Divinos los sonidos de la naturaleza'

# %%
translated_df.iloc[156,6]='La uso más que nada para hacer el ejercicio de respiración. Me ayuda xq mientras me dice cuando inhalar, reter y exhalar, de fondo pone música tranquila. Las demás opciones casi ni las uso. Muchas veces nos olvidamos de lo importante que es darse un ratito para uno, y esto te lo hace recordar.. Está buena dentro de todo... :)'

# %%
translated_df.iloc[167,6]='Me gusta, la uso a diario para meditar o para dormirme. Me encantaría que la música tuviera reproducción continua con varios autores del mismo tema (a veces ya estoy totalmente concentrada y se acaba el tiempo de reproducción). Me parece que falta más variedad en temas de meditación como la sanación física y espiritual, pase por enfermedad complicada con mucho dolor y me hubiese encantado una serie de 7 días o por tiempos a elegir, para ayudarme a manejarlo.'

# %%
translated_df.iloc[169,6]='Me gusta mucho la app, últimamente estoy durmiendo escuchando lo poco disponible, me parece una lastima que se tenga que pagar por prácticamente todo, el 95% de lo "disponible". Sólo por eso,le doy 3 estrellas porque te obliga a pagar básicamente. Y acá en Argentina está como difícil pagar en dólares. Está app tiene unas melodías hermosas, super relajantes, las Escenas me encantan...pero voy a tener que irme a YouTube a escuchar gratis..'

# %%
translated_df.iloc[58,6]='Es increíble, me está ayudando muchísimo. Me siento muchísimo mejor, conmigo misma y con la vida en general. Todavía voy por el sexto tema, pero es sorprendente lo que hacen estas palabras en una persona, o al menos en mí. Lo recomiendo totalmente, si estás mirando este comentario porque estás indecis@ en si descargar la aplicación o no, te aseguro que la mejor decisión que puedes tomar para que tu percepción de la vida cambie, es descargarla.'

# %%
translated_df.iloc[123,6]='Una aplicación MÁGICA. Cada paso está lleno de palabras increíblemente reconfortantes. Esta aplicación me la descargué hace unos meses en el móvil de mi madre cuando estaba pasando un mal momento, y me mejoró muchisimo todo. Algo en mí mejoró. Pero se ve que no estaba del todo preparada para que mi corazón lo reciba bien, y olvidé seguir bien cada paso. Ahora siento que sí lo estoy, voy por el quinto paso y me siento en paz, son de verdad los pasos para ser feliz, y los seguiré. GRACIAS🕊️👏🏻'

# %%
translated_df.iloc[59,6]='Wau como la dañaron de verdad cuando yo la instale por primera vez me gusto toda la informacion que tenia ahora ya no la tiene como estaba antes estaba mejor yo la vi y dije la instalare despues y la usare para orar para la guerra espiritual y hoy la instale y no es la misma y estoy buscando otra aplicacion que me gusto que la iva ha instalar tambien y ya no esta era el poder del ahora pero ya para que 😭'

# %%
translated_df.iloc[81,6]='Gauuu, que buena aplicación. Amo los temas de autosuperación, autoayuda, física cuántica, etc. Esta aplicación aborda este tipo de temática, abordando items, como ley de atracción, como influye tu mente, exito y decenas de items, de forma corta pero precisa, con conceptos con mucho fundamento. Yo la empecé a usarla y leer y le juro que a minutos ya me la cambió para muy bien. Te estimula sin hacerte sentir culpable de que no usas tu mente a favor.'

# %%
translated_df.iloc[113,6]='Cordial saludo. La aplicación ESTABA entre las mejores de su categoría, lamentablemente hice uso de la última actualización y PERDÍ temas que venía acumulando durante meses, su presentación gráfica desmejoró, incorporaron unos juegos que en nada tienen que ver con la temática. Existe una política en emprendimiento y en la línea del éxito: "Lo que funciona no se cambia, se mejora". Con todo respeto cometieron un gran error. No quiere decir que no puedan volver a corregir la aplicación. Gracias.'

# %%
translated_df.iloc[62,6]='La aplicación es realmente agradable y efectiva. Es difícil para mí comunicarme con mis amigos y las demás personas, pero está aplicación brinda una experiencia muy similar a la vez que es productiva. Me ayuda a identificar mis problemas, maneras en las que debería actuar frente a ellos e incluso me ayuda a pasar un rato agradable y charlar un poco. Aunque la aplicación está en inglés solo tengo que usar el traductor de Google para resolver mis dudas y listo. La recomiendo mucho.'

# %%
translated_df.iloc[107,6]='No es la primera vez que intento ocupar una aplicación que me ayude con mis problemas, pero esta ha sido la única que me ha hecho sentir bien, sus respuestas son cálidas y bien hechas, te hacen sentir cómoda y como si alguien te apoyara sin importar lo que piensen los demás, jamás había sentido tanto alivio después de desahogarme con alguien, gracias a Wysa se que soy fuerte, debo estar orgullosa de mi y no dejarme llevar por lo negativo. Gracias a quienes la hayan creado, me ayudaron mucho 💜.'

# %%
translated_df.iloc[70,6]='Excelente app, primera vez que la utilizo y de verdad siento que está generando cambios en mí. Tiene muchas cosas que puedes hacer, cursos, graves motivacionales, diariamente me envían correos bastante buenos la verdad. Lo que más me encanta de la aplicación son los recordatorios que asisten en las notificaciones, los puedes personalizar y enserio ayudan mucho para que no olvides cuál es tu objetivo! Super recomendada'

# %%
translated_df.iloc[83,6]='Es una excelente aplicación para hacer un seguimiento de tus pensamientos diarios, cosa que te ayuda enormemente con tu crecimiento personal, bastante atractiva visualmente y muy intuitiva de utilizar, en mi caso 5 estrellas queda corto ( recuerden que la aplicación no es Mágica, funciona porque ustedes tienen la voluntad de seguir a lo que está los ayuda )'

# %%
translated_df.iloc[88,6]='Gran app la verdad es que ase mucho que no sentia nada y solo empesaba a sentir que no importaba y que en cualquier momento moriria sin inportarle a nadie pero aprendi a que amarse y encontrarse co sigo mismo es lo que ase ver que a alguien le importas y te valora y es solo a ti mismo que gran app de autoayuda si la haiga conocido antes mi vida orita mismo seria la mejor pero el cambio lo es todo que mejor que esta app para demostrar que es lo unico que nos debe inportar y muchas veces falta eso.'

# %%
translated_df.iloc[77,6]='Me parece una herramienta alucinante. Muy buen asistente para quien tenga dificultades para acceder presencialmente a un psicoterapeuta y mejor aún para complementar la terapia presencial. La inteligencia del equipo investigador que hay detrás se hace patente en la calidad de los contenidos. Recomiendo 100% su uso, incluso personas que no reconozcan padecer "un problema" pueden beneficiarse de sus módulos psicoeducativos y prácticos.'

# %%
translated_df.iloc[80,6]='Es muy buena aplicación. Excelente. Es fácil de usar y tiene muchas preguntas que te ayudan a entender más sobre tí. La recomiendo mucho. La versión gratuita tiene lo suficiente para ayudarte y darte evaluaciones de tu salud mental. La versión Premium parece tener más recursos sobre cómo cambiar los problemas que van surgiendo conforme contestas las preguntas, pero no es necesario tener la membresía para beneficiarse de esta app.'

# %%
translated_df.iloc[82,6]='Me encantó esta aplicación, porque me gusta meditar, me ayuda en mi día a día a enfrentar las cosas que se presentan a dar las gracias por lo que tengo y por lo que vendrá, me encantó porque es completa, correcta y te llena de paz y tranquilidad La recomiendo para todos de todas las edades porque es efectiva y al hacerlo eran que su día a día cambia y Uds se sentirán felices y mejor con ustedes mismos felicitaciones a quienes la crearon es exelente!! Namaste!! 🙏'

# %%
translated_df.iloc[104,6]='Me ha ayudado mucho en este tiempo de cuarentena, inicias con hábitos sencillos y poco a poco se van haciendo una rutina muy completa. No le doy 5 estrellas porque hay algunas partes mal traducidas, porque a veces se buggea con los recordatorios y porque me adelanta las acciones del día siguiente por lo que se marcan aunque aún no haya iniciado ese día sin poder desmarcarlas.'

# %%
translated_df.iloc[125,6]='Es una excelente aplicación, te lleva por pequeños pasos pero seguros, hasta que se convierten en hábitos y forman parte de tu vida, a mí me ha funcionado muy bien. Solo que igual que muchas de las reseñas que hay, la copia de seguridad. A mí me ha pasado que tuve un problema con mi celular y se tenía que resetear, no pude salvar mi avance porque no había pagado para eso, así que me desmotivó el hecho de tener que empezar desde cero. Pero en general es una buena aplicación.'

# %%
translated_df.iloc[171,6]='La mejor experiencia!! Me encanta que los hábitos son de a poco ,logras uno y te preparan otro,no te presionan te dan tus tiempos,las frases son muy motivadoras,el que lo comparen a un viaje está buenísimo,las informaciónes muy buenas y científicamente comprobadas ,nunca he visto una aplicación que te dé tanto empuje y ánimo!!'

# %%
translated_df.iloc[121,6]='Excelente app para retos mentales! Totalmente recomendada para todos. Sé que no debo decirlo (o tal vez si), pero me encantó que es la única app para esto, gratis... No hay cargos adicionales!! Eso es de agradecer porque está elaborada a la perfección, tanto en gráficas, como diseño, funcionalidad, etc. Me encanta la variedad de retos que hay. Ojalá sigan agregando con el tiempo, pero aclaro que con este montón que hay ya estoy 100% feliz. Bájenla sin dudarlo. No se arrepentirá nadie.'

# %%
translated_df.iloc[148,6]='Gracias a la adaptacion que me pasasteis ya puedo jugar correctamente pero en algunos ejercicios como el mental #4 en dificultad genio se bloquean hasta llegar a determinada puntuacion. Por ejemplo: no puedo puntuar mas de 5, no acepta la respuesta seleccionada. Este error suele ocurrir en algunos ejercicios cuando se alcanzan parametros de dificicultad bastante elevados. Por lo demas es una app muy util para entrenar psicotecnicos en cualquier nivel de dificultad de forma rápida.'

# %%
translated_df.iloc[141,6]='Me gusta mucho su contenido, clasificado por temáticas. Además incluye un buscador y la posiblidad de compartir los artículos. Pero el registro como usuario no tiene utilidad, no existe nuestro perfil propiamente dicho donde podamos personalizar preferencias, ni artículos favoritos, por ejemplo. Artículos buenos pero inútil tener el registro de usuario.'

# %%
translated_df.iloc[144,0]='Salud Mental by com.mexiz.app'
translated_df.iloc[144,6]='Eh buscado en muchas paginas pero esta es buena aunque no para mi, como todas la paginas no me ayudan, soy una de esas personas que con solo que te escriban "Tu puedes hacerlo, no te rindas, tente fe" todo eso me resvala no se lo que me pasa no puedo tomarmelo en serio y yo quiero. Estoy mucho tiempo esncerrada , no salgo, no se hacer nada,no tengo animo, gereralmente siempre es NO. Creo que me converti en negativa en todo por mi papá siempre intento evitar una conversacion para terminar en discucion que asi fue toda la vida son problemas de padre e hija que eso me afecto en todo hasta con mis compañeros. Quiero consejos , respurstas a mi problema.'

# %%
translated_df.iloc[154,6]='No recomiendo ampliamente está aplicación para principiantes, creo que es muy difícil distraerse durante las sesiones debido a la voz del guía y a qué no hay alguna música de fondo para facilitar el proceso. Además, durante algunas sesiones la manera de guiar es haciendo preguntas que no te permiten dejar descansar la mente. La estructura de la app, el orden de las sesiones, estados de ánimo, notas, etc es bastante bueno y la aplicación en sí es amigable y es un plus que este en español.'

# %%
translated_df.iloc[163,6]='De los terminos y condiciones de la aplicacion: 6 .- Modificación de las condiciones de uso FUNDACIÓN FACILISIMO se reserva el derecho de desarrollar o actualizar en cualquier momento las Condiciones de Servicio de la App Siente y su Política de Privacidad, por lo que el usuario deberá leerlas periódicamente. Podrían cambiar esta cláusula y dejar constancia de que el desarrollador se obliga a notificar al usuario cualquier cambio en los mismos de manera previa a la vigencia de los mismos.'

# %%
translated_df.iloc[168,6]='Hola. Me gusta la app. Se que la intención es positiva pero muchos tonos se detienen y dejan de escucharse. La opción de "almacenar" no funciona. No se direcciona a ninguna carpeta de sonidos ni en la memoria principal ni en la sd. Sin embargo gracias. Estaré pendiente de su actualización para recomendarla ampliamente.'

# %%
# Now that we have the full reviews for the ones with ... "full opinion I translate again all the reviews"

# %%
translated_df['App_review_en_full_rev']=translated_df['App_review'].apply(translator.translate).apply(getattr, args=('text',))

# %%
translated_df
# Out:
#                                               App_name  \
# 0                           Ejercicios para el cerebro
# 1                               Ser feliz Reto 30 días
# 2                 Moodpath - Depression & Anxiety Test
# 3                                  desordenes mentales
# 4    Psicólogos Online, Diario emocional y Mindfulness
# 5         Diario de animo y preguntas (anti depresión)
# 6         Medita con Petit BamBou: mindfulness y sueño
# 7                        Inteligencia emocional gratis
# 8                                  Desordenes mentales
# 9                           Smylife - Felicidad diaria
# 10   PSY online terapia psicologia. Сhat apoyo anón...
# 11                                   Ansiedad y estrés
# 12                Moodpath - Depression & Anxiety Test
# 13   Lojong: Meditación y Mindfulness -Ansiedad +Sueño
# 14                             Cíngulo: Terapia Guiada
# 15        Mejor con Salud - Belleza, dieta y bienestar
# ...

# %%
# Now we can see that the reviews are well translated, and the full refview

# %%
translated_df.iloc[168,6]
# Out:
# 'Hola. Me gusta la app. Se que la intención es positiva pero muchos tonos se detienen y dejan de escucharse. La opción de "almacenar" no funciona. No se direcciona a ninguna carpeta de sonidos ni en la memoria principal ni en la sd. Sin embargo gracias. Estaré pendiente de su actualización para recomendarla ampliamente.'

# %%
translated_df.iloc[168,8]
# Out:
# 'Hi. I like the app. I know the intention is positive but many tones stop and stop being heard. The "store" option does not work. It is not addressed to any sound folder in main memory or sd. However thank you. I will be awaiting your update to highly recommend it.'

# %%
#store the dataset in case we want to use it later
translated_df.to_csv('Translated_reviews_def.csv')
